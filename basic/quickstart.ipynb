# %%
# %%capture --no-stderr
# %pip install promptflow-core

# %%
with open("basic.prompty") as fin:
    print(fin.read())

# %%
import os
from dotenv import load_dotenv

if "AZURE_OPENAI_API_KEY" not in os.environ:
    # load environment variables from .env file
    load_dotenv()

# %%
from promptflow.core import Prompty

# load prompty as a flow
f = Prompty.load(source="basic.prompty")

# execute the flow as function
result = f(question="Who is the president of USA?")
result
# Out:
# 'As of my last update in October 2023, the President of the United States is Joe Biden.'
